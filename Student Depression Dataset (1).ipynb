# %% [markdown]
# # Student Depression Dataset
#
# #### A student depression dataset typically contains data aimed at analyzing, understanding, and predicting depression levels among students. It may include features such as demographic information (age, gender), academic performance (grades, attendance), lifestyle habits (sleep patterns, exercise, social activities), mental health history, and responses to standardized depression scales.
#
# #### These datasets are valuable for research in psychology, data science, and education to identify factors contributing to student depression and to design early intervention strategies. Ethical considerations like privacy, informed consent, and anonymization of data are crucial in working with such sensitive information.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Elvis\Documents\Student Depression Dataset.csv")
df
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')
df
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
df = df[df['Age'] <= 30]
df
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 1           8  Female  24.0  Bangalore    Student                2.0
# 3          30  Female  28.0   Varanasi    Student                3.0
# 4          32  Female  25.0     Jaipur    Student                4.0
# 5          33    Male  29.0       Pune    Student                2.0
# 6          52    Male  30.0      Thane    Student                3.0
# ...       ...     ...   ...        ...        ...                ...
# 27894  140681    Male  23.0   Srinagar    Student                3.0
# 27896  140685  Female  27.0      Surat    Student                5.0
# 27897  140686    Male  27.0   Ludhiana    Student                2.0
# 27899  140690  Female  18.0   Ludhiana    Student                5.0
# 27900  140699    Male  27.0      Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 1                0.0  5.90                 5.0               0.0
# ...

# %%
df.Degree.unique()
# Out:
# array(['BSc', 'BCA', 'M.Tech', 'PhD', 'Class 12', 'B.Ed', 'M.Ed', 'MSc',
#        'BHM', 'M.Pharm', 'MCA', 'MA', 'B.Pharm', 'B.Com', 'MD', 'BE',
#        'BA', 'MBBS', 'B.Arch', 'LLM', 'B.Tech', 'BBA', 'M.Com', 'ME',
#        'MBA', 'LLB', 'Others', 'MHM'], dtype=object)

# %%
df.duplicated()
# Out:
# 1        False
# 3        False
# 4        False
# 5        False
# 6        False
#          ...
# 27894    False
# 27896    False
# 27897    False
# 27899    False
# 27900    False
# Length: 21802, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df_filtered = df[df['Degree'] != "Class 12"]
df_filtered
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 1           8  Female  24.0  Bangalore    Student                2.0
# 3          30  Female  28.0   Varanasi    Student                3.0
# 4          32  Female  25.0     Jaipur    Student                4.0
# 5          33    Male  29.0       Pune    Student                2.0
# 6          52    Male  30.0      Thane    Student                3.0
# ...       ...     ...   ...        ...        ...                ...
# 27891  140645  Female  28.0      Thane    Student                4.0
# 27893  140672  Female  24.0  Hyderabad    Student                3.0
# 27894  140681    Male  23.0   Srinagar    Student                3.0
# 27897  140686    Male  27.0   Ludhiana    Student                2.0
# 27900  140699    Male  27.0      Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 1                0.0  5.90                 5.0               0.0
# ...

# %%
df_filtered.Gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
number_of_males = df_filtered[df_filtered['Gender'] == 'Male'].shape[0]
print(f"Number of males: {number_of_males}")
# Out:
# Number of males: 8816

# %%
number_of_females = df_filtered[df_filtered['Gender'] == 'Female'].shape[0]
print(f"Number of females: {number_of_females}")
# Out:
# Number of females: 7134

# %%
df=df_filtered
df
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 1           8  Female  24.0  Bangalore    Student                2.0
# 3          30  Female  28.0   Varanasi    Student                3.0
# 4          32  Female  25.0     Jaipur    Student                4.0
# 5          33    Male  29.0       Pune    Student                2.0
# 6          52    Male  30.0      Thane    Student                3.0
# ...       ...     ...   ...        ...        ...                ...
# 27891  140645  Female  28.0      Thane    Student                4.0
# 27893  140672  Female  24.0  Hyderabad    Student                3.0
# 27894  140681    Male  23.0   Srinagar    Student                3.0
# 27897  140686    Male  27.0   Ludhiana    Student                2.0
# 27900  140699    Male  27.0      Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 1                0.0  5.90                 5.0               0.0
# ...

# %%
suicidal_thoughts= df[df['Have you ever had suicidal thoughts ?'] == "Yes"]
suicidal_thoughts
# Out:
#            id  Gender   Age      City Profession  Academic Pressure  \
# 3          30  Female  28.0  Varanasi    Student                3.0
# 4          32  Female  25.0    Jaipur    Student                4.0
# 8          59    Male  28.0    Nagpur    Student                3.0
# 15        106    Male  29.0  Srinagar    Student                3.0
# 16        120    Male  25.0    Nashik    Student                5.0
# ...       ...     ...   ...       ...        ...                ...
# 27881  140564    Male  27.0     Surat    Student                4.0
# 27883  140584  Female  22.0    Kanpur    Student                4.0
# 27886  140601  Female  22.0    Jaipur    Student                5.0
# 27894  140681    Male  23.0  Srinagar    Student                3.0
# 27900  140699    Male  27.0     Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 3                0.0  5.59                 2.0               0.0
# ...

# %%
depressed= df[df['Depression'] == 1]
depressed
# Out:
#            id  Gender   Age      City Profession  Academic Pressure  \
# 3          30  Female  28.0  Varanasi    Student                3.0
# 8          59    Male  28.0    Nagpur    Student                3.0
# 12         94    Male  27.0    Kalyan    Student                5.0
# 15        106    Male  29.0  Srinagar    Student                3.0
# 16        120    Male  25.0    Nashik    Student                5.0
# ...       ...     ...   ...       ...        ...                ...
# 27881  140564    Male  27.0     Surat    Student                4.0
# 27883  140584  Female  22.0    Kanpur    Student                4.0
# 27886  140601  Female  22.0    Jaipur    Student                5.0
# 27891  140645  Female  28.0     Thane    Student                4.0
# 27900  140699    Male  27.0     Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 3                0.0  5.59                 2.0               0.0
# ...

# %%
deressed_and_have_had_suicidal_thoughts = depressed[depressed['Have you ever had suicidal thoughts ?'] == "Yes"]
deressed_and_have_had_suicidal_thoughts
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 3          30  Female  28.0   Varanasi    Student                3.0
# 8          59    Male  28.0     Nagpur    Student                3.0
# 15        106    Male  29.0   Srinagar    Student                3.0
# 16        120    Male  25.0     Nashik    Student                5.0
# 22        166  Female  25.0  Ahmedabad    Student                3.0
# ...       ...     ...   ...        ...        ...                ...
# 27878  140547    Male  27.0     Indore    Student                4.0
# 27881  140564    Male  27.0      Surat    Student                4.0
# 27883  140584  Female  22.0     Kanpur    Student                4.0
# 27886  140601  Female  22.0     Jaipur    Student                5.0
# 27900  140699    Male  27.0      Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 3                0.0  5.59                 2.0               0.0
# ...

# %%
gender_counts = df['Gender'].value_counts()
gender_counts
# Out:
# Male      8816
# Female    7134
# Name: Gender, dtype: int64

# %%
plt.figure(figsize=(8, 8)) 
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=0, colors=['skyblue', 'pink']) 
plt.title('Gender Distribution') 
plt.axis('equal')
# Out:
# (-1.0999996749769596,
#  1.0999999845227124,
#  -1.099994157416362,
#  1.0999989982610556)

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Gender', hue='Dietary Habits', data=df, palette=['red', 'blue', 'black','yellow']) 
plt.title('Gender and Dietary Habit Distribution') 
plt.xlabel('Gender') 
plt.ylabel('Count') 
plt.show()

# %%
df.City.unique()
# Out:
# array(['Bangalore', 'Varanasi', 'Jaipur', 'Pune', 'Thane', 'Nagpur',
#        'Kalyan', 'Srinagar', 'Nashik', 'Kolkata', 'Ahmedabad', 'Lucknow',
#        'Surat', 'Ludhiana', 'Bhopal', 'Meerut', 'Agra', 'Chennai',
#        'Hyderabad', 'Vasai-Virar', 'Kanpur', 'Rajkot', 'Ghaziabad',
#        'Faridabad', 'Delhi', 'Patna', 'Mumbai', 'Indore', 'Vadodara',
#        'Visakhapatnam', 'Saanvi', 'M.Tech', 'Less Delhi', '3.0', 'Harsha',
#        'Vaanya', 'Gaurav', 'Harsh', 'Kibara', 'Rashi', 'ME', 'M.Com',
#        'City', 'Nalini', 'Nandini', 'Khaziabad'], dtype=object)

# %%
gender_counts = df.groupby(['City', 'Gender']).size().unstack(fill_value=0)

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(gender_counts, annot=True, fmt="d", cmap="coolwarm", linewidths=.5)
plt.title('Gender Distribution Across Cities')
plt.xlabel('Gender')
plt.ylabel('City')
plt.show()

# %%
plt.figure(figsize=(10, 6)) 
sns.boxplot(x='Study Satisfaction', y='CGPA', data=df, palette='Set2') 
plt.title('Study Satisfaction vs. CGPA') 
plt.xlabel('Study Satisfaction (1.0: Low, 4.0: High)')
plt.ylabel('CGPA') 
plt.grid(True) 
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Financial Stress', y='Work/Study Hours', data=df, palette='Set2')
plt.title('Financial Stress by Work/Study Hours')
plt.xlabel('Financial Stress')
plt.ylabel('Work/Study Hours')
plt.grid(True)
plt.show()
